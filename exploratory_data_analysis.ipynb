# %% [markdown]
# # 动机
#
# - 考虑**社交内聚性较高、彼此之间轨迹又较为相似**的个体组成的社区
# - k-core的优势（计算便捷）
# - k-core的不足（内聚性不足，朋友关系联系不频繁，需要通过是否一起活动过进行验证，不能代表生活中真实的亲密关系）
#
# ```latex
# Rather than being sets of high cohesion, Seidman\cite{seidman1983network} characterizes $k$-cores as "seedbeds, within which cohesive subsets can precipitate out."
#
# @article{cohen2008trusses,
#   title={Trusses: Cohesive subgraphs for social network analysis},
#   author={Cohen, Jonathan},
#   journal={National security agency technical report},
#   volume={16},
#   number={3.1},
#   year={2008},
#   publisher={Citeseer}
# }
#
# @article{seidman1983network,
#   title={Network structure and minimum degree},
#   author={Seidman, Stephen B},
#   journal={Social networks},
#   volume={5},
#   number={3},
#   pages={269--287},
#   year={1983},
#   publisher={Elsevier}
# }
# ```
#
# ```latex
# Social networks can be rife with casual acquaintances and zombie friends who are only nominally "friends" on the online platform, but are not actually close with one another in the real world. However, through the lens of trajectory similarity, it is possible to filter intimate relationships who do frequently hang out together offline.
# ```
#
#
# # 解决思路
#
# 1. 利用轨迹相似度筛选边
# 2. 利用k-core算法进行社区发现
#
# # 相关定义
#
# Notation|Definition
# --------|----------
# $G(V, E)$|a social network, an undirected graph with vertex set $V$ and edge set $E$
# $d(u, v)$|the distance between two users, $u$ and $v$, within the social network $G(V, E)$ ($u, v \in V$)
# $p(φ,λ,t)$|a point on a trajectory, consisting of latitude $φ$, longitude $λ$, and time $t$
# $T$|a trajectory, with $T[i]$ being the $i$th point within the trajectory
# $\mathbf{T}$|a trajectory dataset, with $\mathbf{T}[u]$ being the trajectory of user $u$
# $s(T_1, T_2)$|the similarity between two trajectories, $T_1$ and $T_2$, under a trajectory similarity measure $s$
# $NN(T, k)$|the $k$ nearest neighbors of trajectory $T$
#
# - $u$：社交网络中的一个用户
# - $d(G, u, v)$：社交网络$G$内，用户$u$、$v$之间的距离。
# - $T$：轨迹数据集，其中$T[u]$为用户u的轨迹
# - $τ$：轨迹
# - $s(τ_1, τ_2)$：轨迹$τ_1$、$τ_2$之间的相似度，其中$s$为一轨迹相似度度量。
# - $NN(\mathbf{T}, s, τ, k)$：轨迹数据集$\mathbf{T}$内，在轨迹相似度度量$s$下，轨迹$τ$的$k$-近邻组成的集合。
# - $d_{NN}(\mathbf{T}, s, τ_1, τ_2)$：轨迹数据集$\mathbf{T}$内，在轨迹相似度度量$s$下，轨迹$τ_1$、$τ_2$之间的近邻距离。
#   - $d_{NN}(\mathbf{T}, s, τ_1, τ_2) = \underset {k \in \mathbb{Z}}{\operatorname{argmin}} k, τ_2 \in NN(\mathbf{T}, s, τ_1, k), τ_1 \in NN(\mathbf{T}, s, τ_2, k)$
#
# ```latex
# There are two criteria we can use to identify similar trajectories, $k$-nearest neighbors (K-NN), under which each trajectory is considered to be similar to the $k$ other trajectories with the highest similarity value, as well as $ε$-nearest neighbors, under which pairs of trajectories having similarity values above a threshold $ε$ are considered to be similar \cite{liu2020stccd}. However, $ε$-nearest neighbors is very sensitive to the parameter $ε$ \cite{berton2015graph, berton2018comparison}, and when used to filter edges, it may result in networks with many disconnected parts under an improper value of $ε$. Thus, $k$-nearest neighbors is a better choice. However, $k$-nearest neighbors also has its own problems, such as being a one-way relationship. Consider the situation in which a user is not a sociable person, and his or her trajectory is not very similar to any other user's trajectory. In this situation, $k$-nearest neighbors would still consider the trajectories of $k$ other users to be similar, but should these $k$ users be socially active, it is likely that for each of these users, the $k$-nearest neighbors of his or her trajectory does not include the aforementioned introverted user's trajectory. To overcome such a problem, we propose the following mutual dissimilarity measure for two trajectories based on $k$-nearest neighbors, and use such a dissimilarity measure to filter edges.
#
# @article{liu2020stccd,
#   title={STCCD: Semantic trajectory clustering based on community detection in networks},
#   author={Liu, Caihong and Guo, Chonghui},
#   journal={Expert Systems with Applications},
#   volume={162},
#   pages={113689},
#   year={2020},
#   publisher={Elsevier}
# }
#
# @inproceedings{berton2015graph,
#   title={Graph construction for semi-supervised learning},
#   author={Berton, Lilian and de Andrade Lopes, Alneu},
#   booktitle={Twenty-Fourth International Joint Conference on Artificial Intelligence},
#   year={2015}
# }
#
# @inproceedings{berton2018comparison,
#   title={A comparison of graph construction methods for semi-supervised learning},
#   author={Berton, Lilian and de Andrade Lopes, Alneu and Vega-Oliveros, Didier A},
#   booktitle={2018 International Joint Conference on Neural Networks (IJCNN)},
#   pages={1--8},
#   year={2018},
#   organization={IEEE}
# }
# ```
#
# Mutual Nearest Neighbor Dissimilarity. Given two trajectories, $T_1$ and $T_2$, the Mutual Nearest Neighbor Dissimilarity between $T_1 and T_2$, $d_{MNN}(T_1, T_2)$, is the minimum value of $k \in \mathbb{Z}$ such that $T_2$ is also a $k$-nearest neighbor of $T_1$, and that $T_1$ is a $k$-nearest neighbor of $T_2$. Formally, $d_{MNN}(T_1, T_2) = \underset {k \in \mathbb{Z}}{\operatorname{argmin}} k, T_2 \in NN(T_1, k), T_1 \in NN(T_2, k)$.
#
# Problem Statement. Given (1) a social network $G(V, E)$, (2) a trajectory dataset $\mathbf{T}$ such that $\forall u \in V, \exists! T[u] \in \mathbf{T}$, (3)
#
# ## 如何筛选边？
#
# 一条边$(u, v)$存在，当且仅当$d_{NN}(\mathbf{T}, s, \mathbf{T}[u], \mathbf{T}[v]) \le m$。
#
# 我们可以通过一种基于beam search的算法筛选这样的边。
#
# 时间复杂度：
#
# - 每个节点：$deg(v) \times O(\log m)$
# - 总复杂度：$O(V + E \log m)$
#
# 空间复杂度：$O(E)$
#
# **删边的顺序？**
#
# # 参数
#
# - $d_{NN}(\mathbf{T}, s, \mathbf{T}[u], \mathbf{T}[v]) \le m$中的$m$
# - 利用k-core进行社区发现的参数k
#
# # 实验设计
#
# - 筛选边的运行时间$t$（不同的benchmark、不同的$m$、不同的$k$）
# - 对比k-core，对于每个社区$G'(V', E')$：
#   - 社区的内聚性（社区内任意两个个体之间在社交网络上的平均距离，$\frac{2}{|V'|(|V'| - 1)} \sum_{u, v \in V'}{d(G', u, v)}$，越小越好）
#   - 社区内个体轨迹彼此之间的相似度（社区内任意两个个体轨迹之间的平均近邻距离，$\frac{1}{|V'|(|V'| - 1)} \sum_{u, v \in V'}{(d_{NN}(T, s, \mathbf{T}[u], \mathbf{T}[v]) + d_{NN}(T, s, \mathbf{T}[v], \mathbf{T}[u]))}$，越小越好）
#   - 社区相对于原社区的大小
#   - 社区的密度

# %%
from statistics import mean

# %%
import more_itertools
import networkx as nx
import numpy as np

# %%
from nested_default_dict import NestedDefaultDict
from visualization import *

# %%
original_graph = nx.read_adjlist('social_network/brightkite.txt')

# %%
graphs = {}

for m in (5, 10, 15, 20):
    graphs[m] = nx.read_adjlist(f'filtered_edges/{m}')

# %%
cores = NestedDefaultDict()

# %%
original_cores = NestedDefaultDict()

# %%
def connected_subgraphs(graph):
    for connected_component in nx.connected_components(graph):
        yield graph.subgraph(connected_component)

# %%
def ratios_of_strangers(graph):
    number_of_nodes = len(graph)
    for node in graph.nodes:
        number_of_neighbors = len(graph[node])
        yield (number_of_nodes - number_of_neighbors - 1) / (number_of_nodes)

# %%
def all_pair_nearest_neighbor_distances_from_file(query_nodes, filepath):
    with open(filepath, 'r') as fp:
        for line in fp:
            if line:
                node, *nearest_neighbors = line.split()
                if node in query_nodes:
                    for (distance_minus_one, nearest_neighbor) in enumerate(nearest_neighbors):
                        if nearest_neighbor in query_nodes:
                            # yield (node, nearest_neighbor), distance_minus_one + 1
                            yield distance_minus_one + 1

# %%
def all_pairs_shortest_path_length(graph):
    for node, all_pairs_shortest_path_length_from_node in nx.all_pairs_shortest_path_length(graph):
        yield from all_pairs_shortest_path_length_from_node.values()

# %% [markdown]
# ## k = 3

# %%
original_cores[3] = nx.k_core(original_graph, 3)

# %%
mean(
    more_itertools.collapse(
        (
            all_pairs_shortest_path_length(connected_subgraph)
            for connected_subgraph in connected_subgraphs(original_cores[3])
        )
    )
)
# Out:
# 3.0194061335562776

# %%
nx.density(original_cores[3])
# Out:
# 0.01694587295228284

# %%
nx.average_clustering(original_cores[3])
# Out:
# 0.41398591223824444

# %%
mean(
    more_itertools.collapse(
        (
            all_pair_nearest_neighbor_distances_from_file(connected_subgraph.nodes, 'all_pair_nearest_neighbor_distances')
            for connected_subgraph in connected_subgraphs(original_cores[3])
        )
    )
)
# Out:
# 811.5985999783887

# %%
cores[5][3] = nx.k_core(graphs[5], 3)
visualize_social_network_and_emphasize_communities(cores[5][3]).render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="d1786ea7b8574183ad45e0b752f76bb1" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_d1786ea7b8574183ad45e0b752f76bb1 = echarts.init(
#                     document.getElementById('d1786ea7b8574183ad45e0b752f76bb1'), 'white', {renderer: 'canvas'});
#                 var option_d1786ea7b8574183ad45e0b752f76bb1 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "graph",
#             "layout": "force",
#             "symbolSize": 10,
#             "circular": {
#                 "rotateLabel": false
#             },
#             "force": {
#                 "repulsion": 50,
#                 "edgeLength": 50,
#                 "gravity": 0.2
#             },
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "roam": true,
#             "draggable": false,
#             "focusNodeAdjacency": true,
#             "data": [
#                 {
#                     "name": "22911",
#                     "category": 0
#                 },
#                 {
#                     "name": "9566",
#                     "category": 0
#                 },
#                 {
#                     "name": "1523",
#                     "category": 0
#                 },
#                 {
#                     "name": "1499",
#                     "category": 0
#                 },
#                 {
#                     "name": "959",
#                     "category": 0
#                 },
#                 {
#                     "name": "2896",
#                     "category": 0
#                 },
#                 {
#                     "name": "11765",
#                     "category": 0
#                 },
#                 {
#                     "name": "2001",
#                     "category": 0
#                 },
#                 {
#                     "name": "39936",
#                     "category": 0
#                 },
#                 {
#                     "name": "22913",
#                     "category": 0
#                 },
#                 {
#                     "name": "1076",
#                     "category": 0
#                 },
#                 {
#                     "name": "2880",
#                     "category": 0
#                 },
#                 {
#                     "name": "3",
#                     "category": 0
#                 },
#                 {
#                     "name": "1515",
#                     "category": 0
#                 },
#                 {
#                     "name": "42",
#                     "category": 0
#                 },
#                 {
#                     "name": "124",
#                     "category": 0
#                 },
#                 {
#                     "name": "6910",
#                     "category": 0
#                 },
#                 {
#                     "name": "6902",
#                     "category": 0
#                 },
#                 {
#                     "name": "2881",
#                     "category": 0
#                 },
#                 {
#                     "name": "1143",
#                     "category": 0
#                 },
#                 {
#                     "name": "7170",
#                     "category": 0
#                 },
#                 {
#                     "name": "1875",
#                     "category": 0
#                 },
#                 {
#                     "name": "991",
#                     "category": 0
#                 },
#                 {
#                     "name": "123",
#                     "category": 0
#                 },
#                 {
#                     "name": "6908",
#                     "category": 0
#                 },
#                 {
#                     "name": "659",
#                     "category": 0
#                 },
#                 {
#                     "name": "10353",
#                     "category": 0
#                 },
#                 {
#                     "name": "7",
#                     "category": 0
#                 },
#                 {
#                     "name": "1073",
#                     "category": 0
#                 },
#                 {
#                     "name": "2808",
#                     "category": 0
#                 },
#                 {
#                     "name": "1",
#                     "category": 0
#                 },
#                 {
#                     "name": "993",
#                     "category": 0
#                 },
#                 {
#                     "name": "11",
#                     "category": 0
#                 },
#                 {
#                     "name": "2954",
#                     "category": 0
#                 },
#                 {
#                     "name": "678",
#                     "category": 0
#                 },
#                 {
#                     "name": "2825",
#                     "category": 0
#                 },
#                 {
#                     "name": "961",
#                     "category": 0
#                 },
#                 {
#                     "name": "13789",
#                     "category": 0
#                 },
#                 {
#                     "name": "10238",
#                     "category": 0
#                 }
#             ],
#             "categories": [
#                 {
#                     "name": "default"
#                 }
#             ],
#             "edgeLabel": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "edgeSymbol": [
#                 null,
#                 null
#             ],
#             "edgeSymbolSize": 10,
#             "links": [
#                 {
#                     "source": "22911",
#                     "target": "22913"
#                 },
#                 {
#                     "source": "22911",
#                     "target": "2001"
#                 },
#                 {
#                     "source": "22911",
#                     "target": "11765"
#                 },
#                 {
#                     "source": "9566",
#                     "target": "10238"
#                 },
#                 {
#                     "source": "9566",
#                     "target": "13789"
#                 },
#                 {
#                     "source": "9566",
#                     "target": "39936"
#                 },
#                 {
#                     "source": "1499",
#                     "target": "1515"
#                 },
#                 {
#                     "source": "1499",
#                     "target": "1523"
#                 },
#                 {
#                     "source": "1499",
#                     "target": "1143"
#                 },
#                 {
#                     "source": "1523",
#                     "target": "1515"
#                 },
#                 {
#                     "source": "1523",
#                     "target": "659"
#                 },
#                 {
#                     "source": "2896",
#                     "target": "2880"
#                 },
#                 {

# %%
mean(
    more_itertools.collapse(
        (
            all_pairs_shortest_path_length(connected_subgraph)
            for connected_subgraph in connected_subgraphs(cores[5][3])
        )
    )
)
# Out:
# 1.8054711246200608

# %%
nx.density(cores[5][3])
# Out:
# 0.09176788124156546

# %%
nx.average_clustering(cores[5][3])
# Out:
# 0.7427350427350428

# %%
mean(
    more_itertools.collapse(
        (
            all_pair_nearest_neighbor_distances_from_file(connected_subgraph.nodes, 'all_pair_nearest_neighbor_distances')
            for connected_subgraph in connected_subgraphs(cores[5][3])
        )
    )
)
# Out:
# 21.66551724137931

# %% [markdown]
# ## k = 4

# %%
original_cores[4] = nx.k_core(original_graph, 4)

# %%
mean(
    more_itertools.collapse(
        (
            all_pairs_shortest_path_length(connected_subgraph)
            for connected_subgraph in connected_subgraphs(original_cores[4])
        )
    )
)
# Out:
# 2.925668248279854

# %%
nx.density(original_cores[4])
# Out:
# 0.02065474355021071

# %%
nx.average_clustering(original_cores[4])
# Out:
# 0.4165286339936578

# %%
mean(
    more_itertools.collapse(
        (
            all_pair_nearest_neighbor_distances_from_file(connected_subgraph.nodes, 'all_pair_nearest_neighbor_distances')
            for connected_subgraph in connected_subgraphs(original_cores[4])
        )
    )
)
# Out:
# 804.9643526516936

# %%
cores[5][4] = nx.k_core(graphs[5], 4)
visualize_social_network_and_emphasize_communities(cores[5][4]).render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="5518a77d13654f7f87d4e5e257adb929" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_5518a77d13654f7f87d4e5e257adb929 = echarts.init(
#                     document.getElementById('5518a77d13654f7f87d4e5e257adb929'), 'white', {renderer: 'canvas'});
#                 var option_5518a77d13654f7f87d4e5e257adb929 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "graph",
#             "layout": "force",
#             "symbolSize": 10,
#             "circular": {
#                 "rotateLabel": false
#             },
#             "force": {
#                 "repulsion": 50,
#                 "edgeLength": 50,
#                 "gravity": 0.2
#             },
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "roam": true,
#             "draggable": false,
#             "focusNodeAdjacency": true,
#             "data": [],
#             "categories": [
#                 {
#                     "name": "default"
#                 }
#             ],
#             "edgeLabel": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "edgeSymbol": [
#                 null,
#                 null
#             ],
#             "edgeSymbolSize": 10,
#             "links": []
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "default"
#             ],
#             "selected": {
#                 "default": true
#             }
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     }
# };
#                 chart_5518a77d13654f7f87d4e5e257adb929.setOption(option_5518a77d13654f7f87d4e5e257adb929);
#         });
#     </script>

# %%
cores[10][4] = nx.k_core(graphs[10], 4)
visualize_social_network_and_emphasize_communities(cores[10][4]).render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="d22ecc1b7bdd4bcdb34b236e31ac2bb1" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_d22ecc1b7bdd4bcdb34b236e31ac2bb1 = echarts.init(
#                     document.getElementById('d22ecc1b7bdd4bcdb34b236e31ac2bb1'), 'white', {renderer: 'canvas'});
#                 var option_d22ecc1b7bdd4bcdb34b236e31ac2bb1 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "graph",
#             "layout": "force",
#             "symbolSize": 10,
#             "circular": {
#                 "rotateLabel": false
#             },
#             "force": {
#                 "repulsion": 50,
#                 "edgeLength": 50,
#                 "gravity": 0.2
#             },
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "roam": true,
#             "draggable": false,
#             "focusNodeAdjacency": true,
#             "data": [
#                 {
#                     "name": "6759",
#                     "category": 0
#                 },
#                 {
#                     "name": "36",
#                     "category": 0
#                 },
#                 {
#                     "name": "916",
#                     "category": 0
#                 },
#                 {
#                     "name": "2896",
#                     "category": 0
#                 },
#                 {
#                     "name": "1149",
#                     "category": 0
#                 },
#                 {
#                     "name": "1525",
#                     "category": 0
#                 },
#                 {
#                     "name": "43",
#                     "category": 0
#                 },
#                 {
#                     "name": "1497",
#                     "category": 0
#                 },
#                 {
#                     "name": "2822",
#                     "category": 0
#                 },
#                 {
#                     "name": "42",
#                     "category": 0
#                 },
#                 {
#                     "name": "1140",
#                     "category": 0
#                 },
#                 {
#                     "name": "263",
#                     "category": 0
#                 },
#                 {
#                     "name": "6241",
#                     "category": 0
#                 },
#                 {
#                     "name": "6910",
#                     "category": 0
#                 },
#                 {
#                     "name": "11923",
#                     "category": 0
#                 },
#                 {
#                     "name": "1143",
#                     "category": 0
#                 },
#                 {
#                     "name": "11559",
#                     "category": 0
#                 },
#                 {
#                     "name": "364",
#                     "category": 0
#                 },
#                 {
#                     "name": "680",
#                     "category": 0
#                 },
#                 {
#                     "name": "1875",
#                     "category": 0
#                 },
#                 {
#                     "name": "1880",
#                     "category": 0
#                 },
#                 {
#                     "name": "41",
#                     "category": 0
#                 },
#                 {
#                     "name": "26",
#                     "category": 0
#                 },
#                 {
#                     "name": "6908",
#                     "category": 0
#                 },
#                 {
#                     "name": "9569",
#                     "category": 0
#                 },
#                 {
#                     "name": "10353",
#                     "category": 0
#                 },
#                 {
#                     "name": "250",
#                     "category": 0
#                 },
#                 {
#                     "name": "49",
#                     "category": 0
#                 },
#                 {
#                     "name": "29",
#                     "category": 0
#                 },
#                 {
#                     "name": "1876",
#                     "category": 0
#                 },
#                 {
#                     "name": "6604",
#                     "category": 0
#                 },
#                 {
#                     "name": "4657",
#                     "category": 0
#                 },
#                 {
#                     "name": "1308",
#                     "category": 0
#                 },
#                 {
#                     "name": "1886",
#                     "category": 0
#                 },
#                 {
#                     "name": "0",
#                     "category": 0
#                 },
#                 {
#                     "name": "1076",
#                     "category": 0
#                 },
#                 {
#                     "name": "6923",
#                     "category": 0
#                 },
#                 {
#                     "name": "712",
#                     "category": 0
#                 },
#                 {
#                     "name": "23",
#                     "category": 0
#                 },
#                 {
#                     "name": "5",
#                     "category": 0
#                 },
#                 {
#                     "name": "2929",
#                     "category": 0
#                 },
#                 {
#                     "name": "13",
#                     "category": 0
#                 },
#                 {
#                     "name": "112",
#                     "category": 0
#                 },
#                 {
#                     "name": "10781",
#                     "category": 0
#                 },
#                 {
#                     "name": "1582",
#                     "category": 0
#                 },
#                 {
#                     "name": "10752",
#                     "category": 0
#                 },
#                 {
#                     "name": "658",
#                     "category": 0
#                 },
#                 {
#                     "name": "620",
#                     "category": 0
#                 },
#                 {
#                     "name": "1",
#                     "category": 0
#                 },
#                 {
#                     "name": "40",
#                     "category": 0
#                 },
#                 {
#                     "name": "6641",
#                     "category": 0
#                 },
#                 {
#                     "name": "1546",
#                     "category": 0
#                 },
#                 {
#                     "name": "1180",
#                     "category": 0
#                 },
#                 {
#                     "name": "678",
#                     "category": 0
#                 },
#                 {
#                     "name": "2880",
#                     "category": 0
#                 },
#                 {
#                     "name": "207",
#                     "category": 0

# %%
nx.density(cores[10][4])
# Out:
# 0.047870967741935486

# %%
nx.average_clustering(cores[10][4])
# Out:
# 0.47589206349206375

# %%
mean(
    more_itertools.collapse(
        (
            all_pairs_shortest_path_length(connected_subgraph)
            for connected_subgraph in connected_subgraphs(cores[10][4])
        )
    )
)
# Out:
# 3.804513618677043

# %%
mean(
    more_itertools.collapse(
        (
            all_pair_nearest_neighbor_distances_from_file(connected_subgraph.nodes, 'all_pair_nearest_neighbor_distances')
            for connected_subgraph in connected_subgraphs(cores[10][4])
        )
    )
)
# Out:
# 313.7185714285714

# %% [markdown]
# ## k = 5

# %%
original_cores[5] = nx.k_core(original_graph, 5)

# %%
mean(
    more_itertools.collapse(
        (
            all_pairs_shortest_path_length(connected_subgraph)
            for connected_subgraph in connected_subgraphs(original_cores[5])
        )
    )
)
# Out:
# 2.8431362010780354

# %%
nx.density(original_cores[5])
# Out:
# 0.025447609996898244

# %%
nx.average_clustering(original_cores[5])
# Out:
# 0.4248838046664066

# %%
mean(
    more_itertools.collapse(
        (
            all_pair_nearest_neighbor_distances_from_file(connected_subgraph.nodes, 'all_pair_nearest_neighbor_distances')
            for connected_subgraph in connected_subgraphs(original_cores[5])
        )
    )
)
# Out:
# 790.4356914516809

# %%
cores[10][5] = nx.k_core(graphs[10], 5)
visualize_social_network_and_emphasize_communities(cores[10][5]).render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="14532a09f48d432680ab9c3f4cdec9ea" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_14532a09f48d432680ab9c3f4cdec9ea = echarts.init(
#                     document.getElementById('14532a09f48d432680ab9c3f4cdec9ea'), 'white', {renderer: 'canvas'});
#                 var option_14532a09f48d432680ab9c3f4cdec9ea = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "graph",
#             "layout": "force",
#             "symbolSize": 10,
#             "circular": {
#                 "rotateLabel": false
#             },
#             "force": {
#                 "repulsion": 50,
#                 "edgeLength": 50,
#                 "gravity": 0.2
#             },
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "roam": true,
#             "draggable": false,
#             "focusNodeAdjacency": true,
#             "data": [
#                 {
#                     "name": "7",
#                     "category": 0
#                 },
#                 {
#                     "name": "23",
#                     "category": 0
#                 },
#                 {
#                     "name": "5",
#                     "category": 0
#                 },
#                 {
#                     "name": "9",
#                     "category": 0
#                 },
#                 {
#                     "name": "42",
#                     "category": 0
#                 },
#                 {
#                     "name": "3",
#                     "category": 0
#                 },
#                 {
#                     "name": "46",
#                     "category": 0
#                 },
#                 {
#                     "name": "1",
#                     "category": 0
#                 },
#                 {
#                     "name": "11",
#                     "category": 0
#                 },
#                 {
#                     "name": "26",
#                     "category": 0
#                 },
#                 {
#                     "name": "123",
#                     "category": 0
#                 },
#                 {
#                     "name": "124",
#                     "category": 0
#                 }
#             ],
#             "categories": [
#                 {
#                     "name": "default"
#                 }
#             ],
#             "edgeLabel": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "edgeSymbol": [
#                 null,
#                 null
#             ],
#             "edgeSymbolSize": 10,
#             "links": [
#                 {
#                     "source": "7",
#                     "target": "3"
#                 },
#                 {
#                     "source": "7",
#                     "target": "5"
#                 },
#                 {
#                     "source": "7",
#                     "target": "123"
#                 },
#                 {
#                     "source": "7",
#                     "target": "42"
#                 },
#                 {
#                     "source": "7",
#                     "target": "124"
#                 },
#                 {
#                     "source": "7",
#                     "target": "23"
#                 },
#                 {
#                     "source": "7",
#                     "target": "11"
#                 },
#                 {
#                     "source": "7",
#                     "target": "1"
#                 },
#                 {
#                     "source": "23",
#                     "target": "9"
#                 },
#                 {
#                     "source": "23",
#                     "target": "46"
#                 },
#                 {
#                     "source": "23",
#                     "target": "26"
#                 },
#                 {
#                     "source": "23",
#                     "target": "11"
#                 },
#                 {
#                     "source": "23",
#                     "target": "1"
#                 },
#                 {
#                     "source": "23",
#                     "target": "123"
#                 },
#                 {
#                     "source": "5",
#                     "target": "26"
#                 },
#                 {
#                     "source": "5",
#                     "target": "124"
#                 },
#                 {
#                     "source": "5",
#                     "target": "42"
#                 },
#                 {
#                     "source": "5",
#                     "target": "1"
#                 },
#                 {
#                     "source": "9",
#                     "target": "46"
#                 },
#                 {
#                     "source": "9",
#                     "target": "3"
#                 },
#                 {
#                     "source": "9",
#                     "target": "123"
#                 },
#                 {
#                     "source": "9",
#                     "target": "26"
#                 },
#                 {
#                     "source": "9",
#                     "target": "11"
#                 },
#                 {
#                     "source": "3",
#                     "target": "124"
#                 },
#                 {
#                     "source": "3",
#                     "target": "46"
#                 },
#                 {
#                     "source": "3",
#                     "target": "42"
#                 },
#                 {
#                     "source": "3",
#                     "target": "123"
#                 },
#                 {
#                     "source": "3",
#                     "target": "1"
#                 },
#                 {
#                     "source": "3",
#                     "target": "11"
#                 },
#                 {
#                     "source": "46",
#                     "target": "123"
#                 },
#                 {
#                     "source": "46",
#                     "target": "11"
#                 },
#                 {
#                     "source": "46",
#                     "target": "1"
#                 },
#                 {
#                     "source": "1",
#                     "target": "42"
#                 },
#                 {
#                     "source": "1",
#                     "target": "123"
#                 },
#                 {
#                     "source": "1",
#                     "target": "124"
#                 },
#                 {
#                     "source": "1",
#                     "target": "26"
#                 },
#                 {
#                     "source": "11",
#                     "target": "124"
#                 },
#                 {
#                     "source": "11",
#                     "target": "123"
#                 },
#                 {
#                     "source": "11",
#                     "target": "42"
#                 },
#                 {
#                     "source": "26",
#                     "target": "1

# %%
mean(
    more_itertools.collapse(
        (
            all_pairs_shortest_path_length(connected_subgraph)
            for connected_subgraph in connected_subgraphs(cores[10][5])
        )
    )
)
# Out:
# 1.25

# %%
mean(
    more_itertools.collapse(
        (
            all_pair_nearest_neighbor_distances_from_file(connected_subgraph.nodes, 'all_pair_nearest_neighbor_distances')
            for connected_subgraph in connected_subgraphs(cores[10][5])
        )
    )
)
# Out:
# 62.72727272727273

# %% [markdown]
# ## k = 6

# %%
original_cores[6] = nx.k_core(original_graph, 6)

# %%
mean(
    more_itertools.collapse(
        (
            all_pairs_shortest_path_length(connected_subgraph)
            for connected_subgraph in connected_subgraphs(original_cores[6])
        )
    )
)
# Out:
# 2.7887385190037492

# %%
mean(
    more_itertools.collapse(
        (
            all_pair_nearest_neighbor_distances_from_file(connected_subgraph.nodes, 'all_pair_nearest_neighbor_distances')
            for connected_subgraph in connected_subgraphs(original_cores[6])
        )
    )
)
# Out:
# 776.7600532489388

# %%
cores[10][6] = nx.k_core(graphs[10], 6)
visualize_social_network_and_emphasize_communities(cores[10][6]).render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="c12af1e288e9422d979dd9de4e8b6fed" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_c12af1e288e9422d979dd9de4e8b6fed = echarts.init(
#                     document.getElementById('c12af1e288e9422d979dd9de4e8b6fed'), 'white', {renderer: 'canvas'});
#                 var option_c12af1e288e9422d979dd9de4e8b6fed = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "graph",
#             "layout": "force",
#             "symbolSize": 10,
#             "circular": {
#                 "rotateLabel": false
#             },
#             "force": {
#                 "repulsion": 50,
#                 "edgeLength": 50,
#                 "gravity": 0.2
#             },
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "roam": true,
#             "draggable": false,
#             "focusNodeAdjacency": true,
#             "data": [],
#             "categories": [
#                 {
#                     "name": "default"
#                 }
#             ],
#             "edgeLabel": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "edgeSymbol": [
#                 null,
#                 null
#             ],
#             "edgeSymbolSize": 10,
#             "links": []
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "default"
#             ],
#             "selected": {
#                 "default": true
#             }
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     }
# };
#                 chart_c12af1e288e9422d979dd9de4e8b6fed.setOption(option_c12af1e288e9422d979dd9de4e8b6fed);
#         });
#     </script>

# %%
cores[15][6] = nx.k_core(graphs[15], 6)
visualize_social_network_and_emphasize_communities(cores[15][6]).render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="c80c32967be34e328e5fc413201c1c24" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_c80c32967be34e328e5fc413201c1c24 = echarts.init(
#                     document.getElementById('c80c32967be34e328e5fc413201c1c24'), 'white', {renderer: 'canvas'});
#                 var option_c80c32967be34e328e5fc413201c1c24 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "graph",
#             "layout": "force",
#             "symbolSize": 10,
#             "circular": {
#                 "rotateLabel": false
#             },
#             "force": {
#                 "repulsion": 50,
#                 "edgeLength": 50,
#                 "gravity": 0.2
#             },
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "roam": true,
#             "draggable": false,
#             "focusNodeAdjacency": true,
#             "data": [
#                 {
#                     "name": "56",
#                     "category": 0
#                 },
#                 {
#                     "name": "1582",
#                     "category": 0
#                 },
#                 {
#                     "name": "2896",
#                     "category": 0
#                 },
#                 {
#                     "name": "7",
#                     "category": 0
#                 },
#                 {
#                     "name": "40",
#                     "category": 0
#                 },
#                 {
#                     "name": "5727",
#                     "category": 0
#                 },
#                 {
#                     "name": "74",
#                     "category": 0
#                 },
#                 {
#                     "name": "916",
#                     "category": 0
#                 },
#                 {
#                     "name": "1160",
#                     "category": 0
#                 },
#                 {
#                     "name": "6910",
#                     "category": 0
#                 },
#                 {
#                     "name": "2880",
#                     "category": 0
#                 },
#                 {
#                     "name": "67",
#                     "category": 0
#                 },
#                 {
#                     "name": "23",
#                     "category": 0
#                 },
#                 {
#                     "name": "1948",
#                     "category": 0
#                 },
#                 {
#                     "name": "49",
#                     "category": 0
#                 },
#                 {
#                     "name": "1880",
#                     "category": 0
#                 },
#                 {
#                     "name": "5",
#                     "category": 0
#                 },
#                 {
#                     "name": "11559",
#                     "category": 0
#                 },
#                 {
#                     "name": "92",
#                     "category": 0
#                 },
#                 {
#                     "name": "974",
#                     "category": 0
#                 },
#                 {
#                     "name": "1149",
#                     "category": 0
#                 },
#                 {
#                     "name": "27",
#                     "category": 0
#                 },
#                 {
#                     "name": "2808",
#                     "category": 0
#                 },
#                 {
#                     "name": "4678",
#                     "category": 0
#                 },
#                 {
#                     "name": "12822",
#                     "category": 0
#                 },
#                 {
#                     "name": "1180",
#                     "category": 0
#                 },
#                 {
#                     "name": "12",
#                     "category": 0
#                 },
#                 {
#                     "name": "1073",
#                     "category": 0
#                 },
#                 {
#                     "name": "250",
#                     "category": 0
#                 },
#                 {
#                     "name": "1148",
#                     "category": 0
#                 },
#                 {
#                     "name": "11923",
#                     "category": 0
#                 },
#                 {
#                     "name": "41",
#                     "category": 0
#                 },
#                 {
#                     "name": "0",
#                     "category": 0
#                 },
#                 {
#                     "name": "17",
#                     "category": 0
#                 },
#                 {
#                     "name": "91",
#                     "category": 0
#                 },
#                 {
#                     "name": "4",
#                     "category": 0
#                 },
#                 {
#                     "name": "35",
#                     "category": 0
#                 },
#                 {
#                     "name": "1147",
#                     "category": 0
#                 },
#                 {
#                     "name": "2954",
#                     "category": 0
#                 },
#                 {
#                     "name": "659",
#                     "category": 0
#                 },
#                 {
#                     "name": "11094",
#                     "category": 0
#                 },
#                 {
#                     "name": "29",
#                     "category": 0
#                 },
#                 {
#                     "name": "262",
#                     "category": 0
#                 },
#                 {
#                     "name": "42",
#                     "category": 0
#                 },
#                 {
#                     "name": "11",
#                     "category": 0
#                 },
#                 {
#                     "name": "26",
#                     "category": 0
#                 },
#                 {
#                     "name": "9",
#                     "category": 0
#                 },
#                 {
#                     "name": "51",
#                     "category": 0
#                 },
#                 {
#                     "name": "1875",
#                     "category": 0
#                 },
#                 {
#                     "name": "112",
#                     "category": 0
#                 },
#                 {
#                     "name": "189",
#                     "category": 0
#                 },
#                 {
#                     "name": "703",
#                     "category": 0
#                 },
#                 {
#                     "name": "7170",
#                     "category": 0
#                 },
#                 {
#                     "name": "2929",
#                     "category": 0
#                 },
#                 {
#                     "name": "1",
#                     "category": 0
#                 },
#                 {
#                     "name": "634",
#                     "category": 0
#                 },

# %%
mean(
    more_itertools.collapse(
        (
            all_pairs_shortest_path_length(connected_subgraph)
            for connected_subgraph in connected_subgraphs(cores[15][6])
        )
    )
)
# Out:
# 2.3369597177300796

# %%
mean(
    more_itertools.collapse(
        (
            all_pair_nearest_neighbor_distances_from_file(connected_subgraph.nodes, 'all_pair_nearest_neighbor_distances')
            for connected_subgraph in connected_subgraphs(cores[15][6])
        )
    )
)
# Out:
# 249.91837968561063
